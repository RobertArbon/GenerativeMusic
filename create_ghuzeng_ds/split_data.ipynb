# %%
AUDIO_DIR = './audio'
SPECT_DIR = './spectrograms'
SOURCE_DIR = '/home/lex/Data/Guzheng/Guzheng/categorised by material (traditional school of guzheng playing)'

# %%
import pydub
import re
from pathlib import Path
import typing as T
import numpy as np
import librosa as lr
import soundfile as sf

# %%
def split_audio(
    audio: str,
    output_dir: str,
    duration_ms: int = 5120,
    mono: bool = False,
    extension: str = "wav",
    prompt: str = None
):
    """
    Slice an audio file into clips of the given duration.
    """
    print(Path(audio).name)
    segment = pydub.AudioSegment.from_file(audio)

    if mono:
        segment = segment.set_channels(1)

    output_dir_path = Path(output_dir)
    if not output_dir_path.exists():
        output_dir_path.mkdir(parents=True)

    num_clips_existing = len(list(Path(output_dir_path).glob(f'*.{extension}')))

    segment_duration_ms = int(segment.duration_seconds * 1000)
    num_clips = segment_duration_ms//duration_ms + 1

    meta_data_list = []
    for i in range(num_clips):
        clip_start_ms = i*duration_ms
        clip_end_ms = min(clip_start_ms+duration_ms, segment_duration_ms)
        act_duration_ms = clip_end_ms - clip_start_ms
        clip = segment[clip_start_ms : clip_end_ms]

        # clip_name = f"clip_{i+num_clips_existing}_start_{clip_start_ms}_ms_duration_{act_duration_ms}_ms.{extension}"
        clip_name = f"clip_{i+num_clips_existing}.{extension}"
        clip_path = output_dir_path / clip_name
        clip.export(clip_path, format=extension)
        meta_data = {'file_name': str(clip_path), 'source_file': audio, 
                     'start_ms': clip_start_ms, 'end_ms': clip_end_ms, 
                     'prompt': prompt}
        

        meta_data_list.append(meta_data)
        # print(f"Wrote {clip_path}")
    return meta_data_list

# %%
school_paths = [ x for x in Path(SOURCE_DIR).iterdir()]
extension = 'wav'

prompt_by_path = {}

for school_path in school_paths:
    style = None
    if 'Alienated' in str(school_path): 
        style = 'alienated'
    else:
        style = re.search(r'_ ([A-Za-z]+) [Ss]chool', str(school_path.stem)).group(1).strip()
    
    for fname in school_path.glob(f'*.{extension}'):
        prompt_by_path[str(fname)] = f'Solo Guzheng in the {style} style'

# %%
counter = 0
meta_data_list = []
for file, prompt in prompt_by_path.items(): 
    meta_data = split_audio(file, AUDIO_DIR, prompt=prompt)
    meta_data_list.extend(meta_data)
    counter += 1
# Out:
# 225-249 山東 good sound 2.wav
# 山東 final phrases (bends, high scale, harmonics) 宇涵第一次排練.wav
# vaguely 山東 related- high register double arpeggios, bends.wav
# 山東 宇涵full take 2.wav
# 山東 first section 宇涵第一次排練.wav
# 225-249 山東 good sound 4.wav
# 山東 harmonics 宇涵第一次排練.wav
# 山東 fragment 靖沐dress rehearsal.wav
# 山東 material 1-2 宇涵第一次排練.wav
# 山東 practice (mic noise).wav
# fragment 225 山東 good sound.wav
# 225-242.1 山東 good sound.wav
# 山東 harmonics 3宇涵第一次排練.wav
# 山東 full-01.wav
# 山東 靖沐第一次錄音.wav
# 山東 靖沐dress rehearsal.wav
# 山東 final paragraph 宇涵第一次排練.wav
# 山東 harmonics 2 宇涵第一次排練.wav
# improv (山東 fragment).wav
# 山東 triplets fragment 宇涵第一次排練.wav
# 山東 extract.wav
# 山東 low descending phrases fragment 宇涵第一次排練.wav
# 潮州（full）.wav
# 潮州 full.wav
# 潮州 high register scales bends 靖沐dress rehearsal.wav
# 潮州fragment mid range.wav
# 潮州 宇涵full take2.wav
# 潮州 靖沐第一次錄音.wav
# 潮州 Fragment 靖沐dress rehearsal.wav
# 潮州 final gesture practice fragment 2宇涵第一次排.wav
# 31-147 潮州.wav
# 潮州（三板）full.wav
# 132-147 潮州（三版）.wav
# improv (潮州).wav
# 潮州（三板）fragment.wav
# 潮州 final gesture fragment 宇涵第一次排.wav
# 潮州 靖沐dress rehearsal.wav
# 潮州（full 2）.wav
# 潮州 宇涵第一次排.wav
# 潮州 high register scales bends 2 靖沐dress rehearsal.wav
# improv (possibly 潮州).wav
# fragment- 119-147 潮州（拷牌） distant sound.wav
# 潮州 final gesture practice fragment 宇涵第一次排.wav
# 58-147 潮州（拷牌） good sound.wav
# improv (潮州 including 拷牌、三板）.wav
# 河南 full 1.wav
# 河南 melodic fragment with bend practice 宇涵第一次排.wav
# 河南 fragment 靖沐dress rehearsal.wav
# 河南 low--high fragments 宇涵第一次排.wav
# improv (河南) 2.wav
# 河南 melodic fragment with bend practice 3宇涵第一次排.wav
# 河南 mid-low fragment 宇涵第一次排.wav
# 河南 low note 靖沐dress rehearsal.wav
# 河南 melodic fragment with bend practice 2宇涵第一次排.wav
# 河南 trem plus bend fragment 宇涵第一次排練.wav
# 河南 low register melodic fragment 宇涵第一次排.wav
# 河南 practice fragment 3 宇涵第一次排練.wav
# 河南 melodic fragment 2 宇涵第一次排.wav
# 河南 paragraph 3 (low register) fragment 宇涵第一次排.wav
# 河南 opening paragraph 宇涵第一次排.wav
# 河南 high register bends micro fragment 2 宇涵第一次排練.wav
# 河南 靖沐dress rehearsal.wav
# 河南 full.wav
# 河南 final phrase 宇涵第一次排練.wav
# 河南 mid-high fragment 宇涵第一次排.wav
# 河南 fragment low register 靖沐dress rehearsal.wav
# 河南 宇涵full take 2.wav
# 河南 practice fragment 4 宇涵第一次排練.wav
# 河南 melodic fragment with bend practice 5宇涵第一次排.wav
# 河南 high register fragment 宇涵第一次排練.wav
# 河南 fragment low register 3 靖沐dress rehearsal.wav
# 河南 practice fragment 2 宇涵第一次排練.wav
# 河南 melodic fragment 3宇涵第一次排.wav
# 河南 high register bends micro fragment 宇涵第一次排練.wav
# 河南 high register melodic bends宇涵第一次排練.wav
# 河南 first paragraph 宇涵第一次排練.wav
# 河南 high notes with bend micro fragment 宇涵第一次排練.wav
# 河南 melodic fragment 宇涵第一次排.wav
# 河南 fragment low register 2 靖沐dress rehearsal.wav
# improv (河南).wav
# 河南 practice fragment 宇涵第一次排練.wav
# 河南 practice fragment 5 trems plus harmonic 宇涵第一次排練.wav
# 河南 dyads 靖沐dress rehearsal.wav
# 河南 high notes micro fragment宇涵第一次排練.wav
# 河南 practice fragment 4 trems 宇涵第一次排練.wav
# 河南 靖沐第一次錄音.wav
# 陝西 宇涵第一次排練.wav
# 陝西 fragment 4 靖沐dress rehearsal.wav
# 陝西 fragment 14 靖沐dress rehearsal.wav
# 陝西 full-02.wav
# 陝西 靖沐練習錄音.wav
# 陝西string bend fragment.wav
# 陝西 fragment 13 靖沐dress rehearsal.wav
# 陝西tremolos.wav
# 陝西 fragment 11 靖沐dress rehearsal.wav
# 陝西 fragment 17 靖沐dress rehearsal.wav
# 陝西 靖沐dress rehearsal.wav
# 陝西 fragment 3 靖沐dress rehearsal.wav
# 陝西 fragment 2 靖沐dress rehearsal.wav
# 陝西 full-01.wav
# 陝西 fragment 12 靖沐dress rehearsal.wav
# 陝西 full-03.wav
# 陝西 fragment 靖沐dress rehearsal.wav
# 陝西 fragment 15 靖沐dress rehearsal.wav
# 陝西 fragment 7 靖沐dress rehearsal.wav
# improv (陝西).wav
# 陝西 fragment 8 靖沐dress rehearsal.wav
# 陝西 靖沐第一次錄音.wav
# 陝西string bend fragment 2.wav
# 陝西 fragment 10 靖沐dress rehearsal.wav
# 陝西 fragment 9 靖沐dress rehearsal.wav
# 陝西 fragment 6 靖沐dress rehearsal.wav
# 陝西 fragment 5 靖沐dress rehearsal.wav
# 陝西 fragment 16 靖沐dress rehearsal.wav
# 陝西 full.wav
# 陝西string bend fragment 3.wav
# 陝西 宇涵full take 2.wav
# 客家 靖沐第一次錄音.wav
# 客家 final paragraph practice 宇涵第一次排練.wav
# 客家-01.wav
# 客家 full.wav
# 客家.wav
# 客家 low bends 宇涵第一次排練.wav
# 客家 high register-low register fragment 宇涵第一次排練.wav
# 客家 practice fragment 2 宇涵第一次排練.wav
# 客家 fragment (288-end).wav
# 客家 靖沐dress rehearsal.wav
# 客家 string bends fragment.wav
# improv (客家).wav
# 客家 practice fragment 宇涵第一次排練.wav
# 客家 宇涵 full take 2.wav
# 客家 靖沐練習錄音.wav
# improv (客家) fragment.wav
# 浙江 string bend fragemnt 宇涵第一次排練.wav
# 浙江 material 2 opening gesture fragment 2 宇涵第一次排練.wav
# 浙江 material 3 melodic bend practice fragment 3 宇涵第一次排練.wav
# 浙江 material 3 melodic bend fragment 宇涵第一次排練.wav
# 浙江 quintuplet plus harmonic fragment 宇涵第一次排練.wav
# 浙江 fragment- string bend 4 靖沐dress rehearsal.wav
# 浙江 double arpeggio fragment.wav
# 浙江 low notes 2 靖沐dress rehearsal.wav
# alienated 3 宇涵第一次排練.wav
# alienated 2 fragment 6 宇涵第一次排練.wav
# alienated 1 fragment 5宇涵第一次排.wav
# alienated 1 靖沐dress rehearsal.wav
# alienated 1 靖沐練習錄音.wav
# alienated 3 靖沐練習錄音.wav
# alienated 1 fragment 6 宇涵第一次排.wav
# alienated 3 fragment 靖沐dress rehearsal.wav
# alienated 2-03.wav
# alienated 1-02.wav
# alienated 2 宇涵第一次排練.wav
# alienated 3 靖沐dress rehearsal.wav
# alienated 1 fragment 2 宇涵第一次排.wav
# alienated 3 last phrase 宇涵第一次排練.wav
# alienated 2 靖沐dress rehearsal.wav
# alienated 2 宇涵 full take 2.wav
# alienated 2 fragment 5 宇涵第一次排練.wav
# alienated 1 fragment 4宇涵第一次排.wav
# alienated 1 fragment 宇涵第一次排.wav
# alienated 3 靖沐第一次錄音.wav
# alienated 2 fragment 4 宇涵第一次排練.wav
# Alienated 2a 靖沐dress rehearsal.wav
# alienated 2 fragment 3 宇涵第一次排練.wav
# alienated 2 fragment 2 宇涵第一次排練.wav
# alienated 2 fragment 宇涵第一次排練.wav
# alienated 1-01.wav
# alienated 1 靖沐第一次錄音.wav
# alienated 1 fragment 3 宇涵第一次排.wav
# alienated 2.wav
# alienated 2-01.wav
# alienated 2 靖沐練習錄音.wav
# alienated 3-03.wav
# alienated 1 宇涵full take 2.wav
# alienated 2 靖沐第一次錄音.wav
# alienated 1 宇涵第一次排.wav
# alienated 3 宇涵full take 2.wav
